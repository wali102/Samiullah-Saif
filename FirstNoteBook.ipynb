# %% [markdown]
# <a href="https://colab.research.google.com/github/wali102/Samiullah-Saif/blob/main/FirstNoteBook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
a = 5
b = 4
c = 3

add = a + b + c
print(add)
# Out:
# 12
